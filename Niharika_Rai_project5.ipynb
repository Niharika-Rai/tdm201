# %% [markdown]
# # Project 5 -- Niharika Rai

# %% [markdown]
# **TA Help:** (for instance) John Smith, Alice Jones, etc., list names of any TAs who helped you
#
# - For example: Help with figuring out how to write a function (describe the tasks that they helped you with)
#
# **Collaboration:** My Friend in CS, My Uncle, Another Student, etc., list names of any other people who helped you
#
# (describe the tasks that they helped you with)
# - For example: helped figuring out how to load the dataset.
# - Another example: helped debug error with my plot.
#
# **Internet Resources:** Stack Exchange, Stack Overflow, etc.
#
# (describe any information that you learned from internet resources, including the URLs)
# - data frames in Pandas versus R from StackOverflow  https://stackoverflow.com/questions/8991709/why-were-pandas-merges-in-python-faster-than-data-table-merges-in-r-in-2012
#
# **ChatGPT, Gemini, Claude, etc:** Any language models or generative AI chatbots that helped you.
#
# (if you used any such tools, please tell us here)
# - For example:  I asked ChatGPT how to define a new data frames
# - Another example:  Gemini told me how to make a function for sorting my data
#
# **OVERALL MESSAGE:** Any time that you used anything except your brain to solve the questions in these projects, you need to disclose such resources at the start of the project, with details about your usage of the tools.
#
# **YOUR OWN WORK:** Even when you utilize other resources, do NOT just copy and paste.  Write all explanations in your own words, using several sentences in English, which are understandable and which you wrote (and did not just copy and paste).

# %% [markdown]
# ## Question 1

# %%
# %sql sqlite:////anvil/projects/tdm/data/lahman/lahman.db

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('teamsfranchises',),
#  ('teams',),
#  ('teamshalf',),
#  ('people',),
#  ('allstarfull',),
#  ('appearances',),
#  ('awardsmanagers',),
#  ('awardsplayers',),
#  ('awardssharemanagers',),
#  ('awardsshareplayers',),
#  ('batting',),
#  ('battingpost',),
#  ('schools',),
#  ('collegeplaying',),
#  ('fielding',),
#  ('fieldingof',),
#  ('fieldingofsplit',),
#  ('fieldingpost',),
#  ('halloffame',),
#  ('parks',),
#  ('homegames',),
#  ('managers',),
#  ('managershalf',),
#  ('pitching',),
#  ('pitchingpost',),
#  ('salaries',),
#  ('seriespost',)]

# %%
# %%sql
# SELECT * FROM People
# LIMIT 5
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('aardsda01', 1981, 12, 27, 'Denver', 'USA', 'CO', '', '', '', '', '', '', 'David', 'Aardsma', 'David Allan', 215, 75, 'R', 'R', '2004-04-06', 'aardsda01', '2015-08-23', 'aardd001'),
#  ('aaronha01', 1934, 2, 5, 'Mobile', 'USA', 'AL', 2021, 1, 22, 'USA', 'GA', 'Atlanta', 'Hank', 'Aaron', 'Henry Louis', 180, 72, 'R', 'R', '1954-04-13', 'aaronha01', '1976-10-03', 'aaroh101'),
#  ('aaronto01', 1939, 8, 5, 'Mobile', 'USA', 'AL', 1984, 8, 16, 'USA', 'GA', 'Atlanta', 'Tommie', 'Aaron', 'Tommie Lee', 190, 75, 'R', 'R', '1962-04-10', 'aaronto01', '1971-09-26', 'aarot101'),
#  ('aasedo01', 1954, 9, 8, 'Orange', 'USA', 'CA', '', '', '', '', '', '', 'Don', 'Aase', 'Donald William', 190, 75, 'R', 'R', '1977-07-26', 'aasedo01', '1990-10-03', 'aased001'),
# ...

# %% [markdown]
# 1.1 There are 24 columns in the People table.
# 1.2 The name of the column that contains the player's first name is 'nameFirst'.
# 1.3 For a player's deathYear, if the player is still alive, the column does not show any number written in it. Hence, the column is empty.
# 1.4 Don Aase's player ID is 'aasedo01'.

# %% [markdown]
# ## Question 2

# %%
# %%sql
# SELECT * FROM People WHERE nameLast='Sanders'
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('sandean01', 1974, 3, 2, 'Tucson', 'USA', 'AZ', '', '', '', '', '', '', 'Anthony', 'Sanders', 'Anthony Marcus', 200, 74, 'R', 'R', '1999-04-26', 'sandean01', '2001-04-18', 'sanda001'),
#  ('sandebe01', 1865, 2, 16, 'Catharpin', 'USA', 'VA', 1930, 8, 29, 'USA', 'TN', 'Memphis', 'Ben', 'Sanders', 'Alexander Bennett', 210, 72, 'R', 'R', '1888-06-06', 'sandebe01', '1892-10-14', 'sandb101'),
#  ('sandeda01', 1979, 8, 29, 'Oklahoma City', 'USA', 'OK', '', '', '', '', '', '', 'David', 'Sanders', 'David Andrew', 200, 72, 'L', 'L', '2003-04-23', 'sandeda01', '2005-09-10', 'sandd002'),
#  ('sandede01', 1921, 4, 8, 'Quitman', 'USA', 'TX', 2007, 8, 17, 'USA', 'OK', 'McAlester', 'Dee', 'Sanders', 'Dee Wilman', 195, 75, 'R', 'R', '1945-08-12', 'sandede01', '1945-08-13', 'sandd101'),
# ...

# %%
# %%sql
# SELECT * FROM People WHERE nameLast='Sanders' AND birthYear<1900
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('sandebe01', 1865, 2, 16, 'Catharpin', 'USA', 'VA', 1930, 8, 29, 'USA', 'TN', 'Memphis', 'Ben', 'Sanders', 'Alexander Bennett', 210, 72, 'R', 'R', '1888-06-06', 'sandebe01', '1892-10-14', 'sandb101'),
#  ('sandero01', 1892, 8, 1, 'Stafford', 'USA', 'KS', 1950, 1, 17, 'USA', 'MO', 'Kansas City', 'Roy', 'Sanders', 'Roy Garvin', 195, 72, 'R', 'R', '1917-04-16', 'sandero01', '1918-08-27', 'sandr104'),
#  ('sandero02', 1894, 6, 10, 'Pittsburg', 'USA', 'KS', 1963, 7, 8, 'USA', 'KY', 'Louisville', 'Roy', 'Sanders', 'Roy Lee', 185, 72, 'R', 'R', '1918-08-06', 'sandero02', '1920-05-31', 'sandr101'),
#  ('sandewa01', 1877, 8, 2, 'Maynardville', 'USA', 'TN', 1962, 8, 3, 'USA', 'TN', 'Chattanooga', 'War', 'Sanders', 'Warren Williams', 160, 70, 'R', 'L', '1903-04-18', 'sandewa01', '1904-07-04', 'sandw101')]

# %%
# %%sql
# SELECT * FROM People WHERE nameLast='Sanders' AND (birthYear<1900 OR birthYear>1975)
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('sandebe01', 1865, 2, 16, 'Catharpin', 'USA', 'VA', 1930, 8, 29, 'USA', 'TN', 'Memphis', 'Ben', 'Sanders', 'Alexander Bennett', 210, 72, 'R', 'R', '1888-06-06', 'sandebe01', '1892-10-14', 'sandb101'),
#  ('sandeda01', 1979, 8, 29, 'Oklahoma City', 'USA', 'OK', '', '', '', '', '', '', 'David', 'Sanders', 'David Andrew', 200, 72, 'L', 'L', '2003-04-23', 'sandeda01', '2005-09-10', 'sandd002'),
#  ('sandeph01', 1995, 6, 5, 'Augsburg', 'Germany', 'Bavaria', '', '', '', '', '', '', 'Phoenix', 'Sanders', 'Phoenix Clark', 205, 70, 'R', 'R', '2022-04-14', 'sandeph01', '2022-07-10', 'sandp003'),
#  ('sandero01', 1892, 8, 1, 'Stafford', 'USA', 'KS', 1950, 1, 17, 'USA', 'MO', 'Kansas City', 'Roy', 'Sanders', 'Roy Garvin', 195, 72, 'R', 'R', '1917-04-16', 'sandero01', '1918-08-27', 'sandr104'),
# ...

# %% [markdown]
# I followed the code syntax rules provided by the question to formulate my queries. 2.1 and 2.2 were shown in the question. I read the 'Important' tip to formulate 2.3.

# %% [markdown]
# ## Question 3

# %%
# %%sql
# SELECT * FROM People WHERE birthYear>1970 AND height>70 ORDER BY nameLast DESC LIMIT 10
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('vanderi01', 1985, 5, 22, 'Eindhoven', 'Netherlands', 'North Brabant', '', '', '', '', '', '', 'Rick', 'van den Hurk', 'Henricus Nicolas', 215, 77, 'R', 'R', '2007-04-10', 'vanderi01', '2012-10-03', 'vandr001'),
#  ('dendema01', 1987, 8, 10, 'Fort Lauderdale', 'USA', 'FL', '', '', '', '', '', '', 'Matt', 'den Dekker', 'Matthew Gerrit', 210, 74, 'L', 'L', '2013-08-29', 'dendema01', '2018-07-26', 'dendm001'),
#  ('degroja01', 1988, 6, 19, 'DeLand', 'USA', 'FL', '', '', '', '', '', '', 'Jacob', 'deGrom', 'Jacob Anthony', 185, 76, 'L', 'R', '2014-05-15', 'degroja01', '2022-09-30', 'degrj001'),
#  ('deloslu02', 1977, 11, 1, 'Santo Domingo', 'D.R.', 'Distrito Nacional', '', '', '', '', '', '', 'Luis', 'de los Santos', 'Luis', 216, 74, 'R', 'R', '2002-07-20', 'deloslu02', '2002-07-31', 'delol002'),
# ...

# %%
# %%sql
# SELECT * FROM People WHERE birthYear>1970 AND height>70 ORDER BY nameLast DESC LIMIT 20
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# (sqlite3.OperationalError) Could not decode to UTF-8 column 'nameLast' with text 'Zu�iga'
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# SELECT * FROM People WHERE (nameLast NOT LIKE '%�%') AND (birthYear>1970 AND height>70) ORDER BY nameLast DESC LIMIT 20
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('vanderi01', 1985, 5, 22, 'Eindhoven', 'Netherlands', 'North Brabant', '', '', '', '', '', '', 'Rick', 'van den Hurk', 'Henricus Nicolas', 215, 77, 'R', 'R', '2007-04-10', 'vanderi01', '2012-10-03', 'vandr001'),
#  ('dendema01', 1987, 8, 10, 'Fort Lauderdale', 'USA', 'FL', '', '', '', '', '', '', 'Matt', 'den Dekker', 'Matthew Gerrit', 210, 74, 'L', 'L', '2013-08-29', 'dendema01', '2018-07-26', 'dendm001'),
#  ('degroja01', 1988, 6, 19, 'DeLand', 'USA', 'FL', '', '', '', '', '', '', 'Jacob', 'deGrom', 'Jacob Anthony', 185, 76, 'L', 'R', '2014-05-15', 'degroja01', '2022-09-30', 'degrj001'),
#  ('deloslu02', 1977, 11, 1, 'Santo Domingo', 'D.R.', 'Distrito Nacional', '', '', '', '', '', '', 'Luis', 'de los Santos', 'Luis', 216, 74, 'R', 'R', '2002-07-20', 'deloslu02', '2002-07-31', 'delol002'),
# ...

# %% [markdown]
# I followed the SQL syntax examples given under this question to write my query for 3.1 and 3.2. I also read the 'Hint' note to write my query for 3.3.

# %% [markdown]
# ## Question 4

# %%
# %%sql
# SELECT *, AVG(weight) AS avg_weight FROM People GROUP BY birthYear ORDER BY avg_weight DESC LIMIT 10;
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('adamsau01', 1986, 8, 19, 'Montgomery', 'USA', 'AL', '', '', '', '', '', '', 'Austin', 'Adams', 'Austin David', 205, 71, 'R', 'R', '2014-07-12', 'adamsau01', '2019-07-06', 'adama001', 212.62264150943398),
#  ('abreuto01', 1984, 11, 13, 'Puerto Plata', 'D.R.', 'Puerto Plata', '', '', '', '', '', '', 'Tony', 'Abreu', 'Etanislao Toni', 200, 70, 'B', 'R', '2007-05-22', 'abreuto01', '2014-07-28', 'abret001', 212.3913043478261),
#  ('achteaj01', 1988, 8, 27, 'Toledo', 'USA', 'OH', '', '', '', '', '', '', 'A. J.', 'Achter', 'Adam Joseph', 215, 77, 'R', 'R', '2014-09-03', 'achteaj01', '2016-10-01', 'achta001', 211.9375),
#  ('aguilje01', 1990, 6, 30, 'Maracay', 'Venezuela', 'Aragua', '', '', '', '', '', '', 'Jesus', 'Aguilar', 'Jesus Alexander', 277, 75, 'R', 'R', '2014-05-15', 'aguilje01', '2022-10-05', 'aguij001', 211.6100386100386),
# ...

# %% [markdown]
# I followed the SQL syntax example for this question and combined it with the syntax examples of the previous question to write my query. The output shows a new column called, 'avg_weight' has been created that shows the average weights of the players, grouped by their birth year, in descending order.

# %% [markdown]
# ## Question 5

# %%
# %%sql
# SELECT COUNT(*) FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [(27,)]

# %%
# %%sql
# SELECT COUNT(*) FROM People WHERE birthYear<1900 AND height>74
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [(767,)]

# %% [markdown]
# For 5.1, I used the sample query from question 1 that lists all the names of the tables in the Lahman dataset. However, I replaced the 'name' part of that query with 'COUNT(*)' to get the number of all the tables instead in the Lahman dataset.
# For 5.2, I used the SQL syntax from the previous question and used 'WHERE' and 'AND' to write my query. However, since I did not just want to list those rows but find their count, I also used 'COUNT(*)' in my SQL syntax to count all the rows that satisfied these 2 conditions.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
#
# https://www.purdue.edu/odos/osrr/honor-pledge/
